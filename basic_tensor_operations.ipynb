# %% [markdown]
# # 1. Tensor operations

# %%
import torch

# %% [markdown]
# ## Tensor creation and gradient operations

# %%
# Defining random variables

x = torch.tensor(3.0)
b = torch.tensor(2.0, requires_grad=True)
w = torch.tensor(1.0, requires_grad=True)

# %%
# Defining the output function
y = w * x + b

# %%
# Compute derivatives on y 
y.backward()

# %% [markdown]
# dy/dw is the gradient of y with respect to w, which is a tensor stored in w.grad
#
# Same things for all variables where requires_grad=True
#
# ```python

# %%
# Displaying gradients
print("dy/db:", b.grad) # Gradient of y with respect to b 
print("dy/dw:", w.grad) # Gradient of y with respect to w
print("dy/dx:", x.grad) # Gradient of y with respect to x (should be None since x does not require grad)

# This returns a tensor. If you want the value as a float, you can use .item()
print("dy/db (as float):", b.grad.item())  # Gradient of y with respect to b as float
# Out:
# dy/db: tensor(1.)
# dy/dw: tensor(3.)
# dy/dx: None
# dy/db (as float): 1.0

# %% [markdown]
# ## Tensor interaction with numpy

# %%
import numpy as np

# %%
r = np.random.rand(3, 2)

# Convert to a PyTorch tensor
t = torch.tensor(r, dtype=torch.float32)

# %%
# Get the type of each
print("Type of tensor t:", t.dtype)  # Should print torch.float32
print("Type of numpy array r:", r.dtype)  # Should print float64
# Out:
# Type of tensor t: torch.float32
# Type of numpy array r: float64

# %%
# Convert from PyTorch tensor to numpy array
r_converted = t.numpy()

# %% [markdown]
# # 2. Linear regression

# %%
import pandas as pd

# %%
house = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Boston.csv')

# %%
house.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## First option: training with scikit learn

# %%
y = house['MEDV']
X = house.drop(columns=['MEDV'])

# %%
# Splitting the dataset into training and testing sets

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
# # check shape of train and test sample
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 13), (152, 13), (354,), (152,))

# %%
# Select a linear regression model
from sklearn.linear_model import LinearRegression
# Create a linear regression model
model = LinearRegression()

# %%
# Fit the model to the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model's performance
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Display the coefficients of the model
print("Coefficients:", model.coef_)
# Display the intercept of the model
print("Intercept:", model.intercept_)
# Display the first 5 predictions
print("First 5 predictions:", y_pred[:5])
# Display the first 5 actual values
print("First 5 actual values:", y_test[:5].values)
# Scatter plot of actual vs predicted values
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
# Out:
# Mean Squared Error: 20.718012877838557
# R-squared: 0.6551914852365515
# Coefficients: [-1.29412069e-01  3.65184937e-02  1.54418944e-02  2.35486887e+00
#  -2.04171489e+01  4.41356565e+00  4.61075512e-03 -1.58626723e+00
#   2.51478665e-01 -9.59591213e-03 -9.64169204e-01  1.00972679e-02
#  -5.43198745e-01]
# Intercept: 34.21916368863032
# First 5 predictions: [31.71733828 22.02143302 21.16613197 39.77837246 20.10258512]
# First 5 actual values: [31.5 19.3 19.3 41.7 17.7]
# Text(0.5, 1.0, 'Actual vs Predicted Values')

# %% [markdown]
# ## Other option: training with pytorch

# %%
# Training data (making the dataframe into a tensor)

X_torch = torch.tensor(X.values, dtype=torch.float32, requires_grad=True)
y_torch = torch.tensor(y.values, dtype=torch.float32, requires_grad=True)

# %%
print("Shape of X_torch:", X_torch.shape)
print("Shape of y_torch:", y_torch.shape)
# Out:
# Shape of X_torch: torch.Size([506, 13])
# Shape of y_torch: torch.Size([506])

# %%
# Defining a weight and bias for a linear model
w = torch.randn(X_torch.shape[1], requires_grad=True)  # Random weights
b = torch.randn(1, requires_grad=True)  # Random bias

print("Initial weights:", w)
print("Shape of weights:", w.shape)
print("Initial bias:", b)
# Out:
# Initial weights: tensor([ 1.8064, -0.5702, -1.0813, -0.6298,  1.5258,  0.9243, -1.2849,  0.5079,
#         -0.6512,  0.8787,  0.8845,  2.0484,  0.9840], requires_grad=True)
# Shape of weights: torch.Size([13])
# Initial bias: tensor([-0.2209], requires_grad=True)

# %% [markdown]
# DISCLAIMER : All tensors should be the same dtype.

# %%
# Defining the linear model
def linear_model(X, w, b):
    return X @ w + b  # Matrix multiplication and addition of bias

# %%
# Generating rubbish predictions
rubbish_predictions = linear_model(X_torch, w, b)

# %%
# Calculating the loss using Mean Squared Error
def mean_squared_error(y_true, y_pred):
    return torch.mean((y_true - y_pred) ** 2)

# %%
loss = mean_squared_error(y_torch, rubbish_predictions)
print("Initial loss:", loss.item())
# Out:
# Initial loss: 1026839.8125

# %%
loss.backward()  # Compute gradients

# %%
w.grad, b.grad  # Access gradients
# Out:
# (tensor([7.5535e+03, 2.2207e+04, 2.2600e+04, 1.3678e+02, 1.1098e+03, 1.2504e+04,
#          1.3686e+05, 7.5321e+03, 1.9856e+04, 8.3409e+05, 3.6988e+04, 7.3397e+05,
#          2.5378e+04]),
#  tensor([1995.1416]))

# %%
### VERY IMPORTANT: Zero the gradients before the next iteration
w.grad.zero_()
b.grad.zero_()  # Zero the gradients for bias
# Out:
# tensor([0.])

# %% [markdown]
# Otherwise, calling loss.backward will add the gradients to the existing ones, which is not what we want.
#
# ```python

# %%
# Loss was exploding - might be wildly different scales in X
# Normalizing the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.values)  # Fit and transform the features
X_torch_scaled = torch.tensor(X_scaled, dtype=torch.float32, requires_grad=True)  # Convert to tensor
# Re-initialize weights and bias
w = torch.randn(X_torch_scaled.shape[1], requires_grad=True)  # Random weights
b = torch.randn(1, requires_grad=True)  # Random bias

# %%
#Again
def gradient_descent_step(w, b, X, y, learning_rate=1e-4, verbose=False):
    """Perform a single step of gradient descent with gradient clipping."""
    predictions = linear_model(X, w, b)
    loss = mean_squared_error(y, predictions)
    loss.backward()

    if verbose:
        print(f"Loss before update: {loss.item():.6f}")
        print(f"Weight grad norm: {w.grad.norm():.6f}, Bias grad: {b.grad.item():.6f}")

    # 🚨 Gradient Clipping: prevent exploding gradients
    #torch.nn.utils.clip_grad_norm_([w, b], max_norm=1.0)

    with torch.no_grad():
        w -= learning_rate * w.grad
        b -= learning_rate * b.grad

        # Optional: Clamp weights to a reasonable range (extra safety)
        #w.clamp_(-10, 10)
        #b.clamp_(-10, 10)

    w.grad.zero_()
    b.grad.zero_()

    if verbose:
        new_loss = mean_squared_error(y, linear_model(X, w, b))
        print(f"Updated weights: {w}")
        print(f"Updated bias: {b}")
        print(f"Loss after update: {new_loss.item():.6f}")

    return w, b

# %%
# Training the model using gradient descent - 100 epochs
for epoch in range(1000):
    w, b = gradient_descent_step(w, b, X_torch_scaled, y_torch, learning_rate=0.01, verbose=(epoch % 10 == 0))
# Out:
# Loss before update: 611.130188
# Weight grad norm: 30.442801, Bias grad: -45.986614
# Updated weights: tensor([ 0.2437, -0.9938,  0.3028,  2.7226,  1.4381,  2.1959, -0.8103, -0.1774,
#          0.6336, -2.0043,  1.3695,  1.7538,  0.1412], requires_grad=True)
# Updated bias: tensor([-0.0006], requires_grad=True)
# Loss after update: 581.451111
# Loss before update: 396.548920
# Weight grad norm: 10.853824, Bias grad: -37.574409
# Updated weights: tensor([-0.0905, -0.4361, -0.2013,  2.4581,  0.9657,  2.8705, -1.2165,  0.0799,
#          0.3445, -2.3493,  0.6726,  1.8372, -0.6477], requires_grad=True)
# Updated bias: tensor([4.1213], requires_grad=True)
# Loss after update: 381.437073
# Loss before update: 272.211121
# Weight grad norm: 6.518062, Bias grad: -30.701029
# Updated weights: tensor([-0.1700, -0.1963, -0.3227,  2.2284,  0.8473,  3.2397, -1.2827,  0.0071,
#          0.3738, -2.3504,  0.2692,  1.7434, -1.0450], requires_grad=True)
# Updated bias: tensor([7.4893], requires_grad=True)
# Loss after update: 262.461334
# Loss before update: 190.520691
# Weight grad norm: 5.149135, Bias grad: -25.084976
# Updated weights: tensor([-0.1911, -0.0597, -0.3414,  2.0272,  0.8117,  3.4772, -1.2611, -0.1402,
#          0.4714, -2.2742, -0.0188,  1.6257, -1.3098], requires_grad=True)
# Updated bias: tensor([10.2412], requires_grad=True)
# Loss after update: 184.028473
# Loss before update: 135.993759
# Weight grad norm: 4.298683, Bias grad: -20.496252
# Updated weights: tensor([-0.2038,  0.0357, -0.3333,  1.8511,  0.7881,  3.6406, -1.2193, -0.2952,
#          0.5735, -2.1896, -0.2465,  1.5204, -1.5173], requires_grad=True)
# Updated bias: tensor([12.4896], requires_grad=True)
# Loss after update: 131.651566
# Loss before update: 99.498947
# Weight grad norm: 3.650854, Bias grad: -16.746931
# Updated weights: tensor([-0.2192,  0.1098, -0.3188,  1.6973,  0.7596,  3.7540, -1.1750, -0.4415,
#          0.6660, -2.1128, -0.4342,  1.4332, -1.6917], requires_grad=True)
# Updated bias: tensor([14.3268], requires_grad=True)
# Loss after update: 96.590141
# Loss before update: 75.035431
# Weight grad norm: 3.143146, Bias grad: -13.683463
# Updated weights: tensor([-0.2387,  0.1701, -0.3036,  1.5633,  0.7235,  3.8306, -1.1327, -0.5762,
#          0.7472, -2.0462, -0.5917,  1.3625, -1.8426], requires_grad=True)
# Updated bias: tensor([15.8279], requires_grad=True)
# Loss after update: 73.083702
# Loss before update: 58.607567
# Weight grad norm: 2.743273, Bias grad: -11.180386
# Updated weights: tensor([-0.2614,  0.2206, -0.2891,  1.4469,  0.6804,  3.8791, -1.0932, -0.6999,
#          0.8185, -1.9889, -0.7253,  1.3053, -1.9751], requires_grad=True)
# Updated bias: tensor([17.0544], requires_grad=True)
# Loss after update: 57.295296
# Loss before update: 47.550133
# Weight grad norm: 2.427141, Bias grad: -9.135190
# Updated weights: tensor([-0.2861,  0.2638, -0.2757,  1.3461,  0.6317,  3.9060, -1.0563, -0.8136,
#          0.8818, -1.9394, -0.8394,  1.2588, -2.0926], requires_grad=True)
# Updated bias: tensor([18.0566], requires_grad=True)
# Loss after update: 46.665382
# Loss before update: 40.084518
# Weight grad norm: 2.175810, Bias grad: -7.464111
# Updated weights: tensor([-0.3118,  0.3011, -0.2634,  1.2589,  0.5787,  3.9165, -1.0218, -0.9187,
#          0.9385, -1.8964, -0.9376,  1.2208, -2.1977], requires_grad=True)
# Updated bias: tensor([18.8754], requires_grad=True)
# Loss after update: 39.485867
# Loss before update: 35.023361
# Weight grad norm: 1.974367, Bias grad: -6.098724
# Updated weights: tensor([-0.3378,  0.3341, -0.2523,  1.1835,  0.5224,  3.9142, -0.9893, -1.0161,
#          0.9900, -1.8589, -1.0226,  1.1895, -2.2923], requires_grad=True)
# Updated bias: tensor([19.5444], requires_grad=True)
# Loss after update: 34.616329
# Loss before update: 31.573589
# Weight grad norm: 1.811161, Bias grad: -4.983097
# Updated weights: tensor([-0.3636,  0.3635, -0.2421,  1.1186,  0.4639,  3.9024, -0.9586, -1.1068,
#          1.0371, -1.8258, -1.0967,  1.1634, -2.3779], requires_grad=True)
# Updated bias: tensor([20.0911], requires_grad=True)
# Loss after update: 31.295088
# Loss before update: 29.205372
# Weight grad norm: 1.677180, Bias grad: -4.071556
# Updated weights: tensor([-0.3888,  0.3901, -0.2330,  1.0627,  0.4039,  3.8835, -0.9294, -1.1916,
#          1.0807, -1.7966, -1.1617,  1.1415, -2.4559], requires_grad=True)
# Updated bias: tensor([20.5377], requires_grad=True)
# Loss after update: 29.013224
# Loss before update: 27.564442
# Weight grad norm: 1.565519, Bias grad: -3.326756
# Updated weights: tensor([-0.4130,  0.4145, -0.2246,  1.0146,  0.3428,  3.8592, -0.9014, -1.2711,
#          1.1213, -1.7706, -1.2190,  1.1228, -2.5274], requires_grad=True)
# Updated bias: tensor([20.9027], requires_grad=True)
# Loss after update: 27.430445
# Loss before update: 26.413847
# Weight grad norm: 1.470940, Bias grad: -2.718197
# Updated weights: tensor([-0.4363,  0.4370, -0.2171,  0.9733,  0.2814,  3.8311, -0.8747, -1.3459,
#          1.1594, -1.7473, -1.2700,  1.1067, -2.5931], requires_grad=True)
# Updated bias: tensor([21.2009], requires_grad=True)
# Loss after update: 26.319128
# Loss before update: 25.594954
# Weight grad norm: 1.389501, Bias grad: -2.220966
# Updated weights: tensor([-0.4584,  0.4581, -0.2103,  0.9378,  0.2198,  3.8003, -0.8490, -1.4165,
#          1.1955, -1.7265, -1.3155,  1.0926, -2.6538], requires_grad=True)
# Updated bias: tensor([21.4445], requires_grad=True)
# Loss after update: 25.526867
# Loss before update: 25.001436
# Weight grad norm: 1.318246, Bias grad: -1.814693
# Updated weights: tensor([-0.4794,  0.4780, -0.2041,  0.9073,  0.1585,  3.7677, -0.8241, -1.4832,
#          1.2296, -1.7077, -1.3564,  1.0802, -2.7101], requires_grad=True)
# Updated bias: tensor([21.6436], requires_grad=True)
# Loss after update: 24.951504
# Loss before update: 24.561964
# Weight grad norm: 1.254966, Bias grad: -1.482739
# Updated weights: tensor([-0.4993,  0.4968, -0.1984,  0.8811,  0.0977,  3.7341, -0.8001, -1.5465,
#          1.2622, -1.6908, -1.3934,  1.0692, -2.7625], requires_grad=True)
# Updated bias: tensor([21.8063], requires_grad=True)
# Loss after update: 24.524487
# Loss before update: 24.228582
# Weight grad norm: 1.198014, Bias grad: -1.211506
# Updated weights: tensor([-0.5180,  0.5147, -0.1933,  0.8587,  0.0376,  3.7000, -0.7768, -1.6066,
#          1.2934, -1.6755, -1.4271,  1.0592, -2.8114], requires_grad=True)
# Updated bias: tensor([21.9392], requires_grad=True)
# Loss after update: 24.199732
# Loss before update: 23.969002
# Weight grad norm: 1.146152, Bias grad: -0.989887
# Updated weights: tensor([-0.5356,  0.5318, -0.1886,  0.8394, -0.0216,  3.6657, -0.7542, -1.6638,
#          1.3232, -1.6617, -1.4578,  1.0500, -2.8571], requires_grad=True)
# Updated bias: tensor([22.0478], requires_grad=True)
# Loss after update: 23.946192
# Loss before update: 23.761404
# Weight grad norm: 1.098452, Bias grad: -0.808815
# Updated weights: tensor([-0.5522,  0.5482, -0.1843,  0.8228, -0.0799,  3.6317, -0.7322, -1.7183,
#          1.3520, -1.6492, -1.4860,  1.0416, -2.9000], requires_grad=True)
# Updated bias: tensor([22.1365], requires_grad=True)
# Loss after update: 23.742886
# Loss before update: 23.590994
# Weight grad norm: 1.054212, Bias grad: -0.660858
# Updated weights: tensor([-0.5679,  0.5640, -0.1803,  0.8086, -0.1371,  3.5981, -0.7108, -1.7704,
#          1.3796, -1.6379, -1.5120,  1.0337, -2.9402], requires_grad=True)
# Updated bias: tensor([22.2090], requires_grad=True)
# Loss after update: 23.575581
# Loss before update: 23.447699
# Weight grad norm: 1.012894, Bias grad: -0.539963
# Updated weights: tensor([-0.5826,  0.5792, -0.1766,  0.7964, -0.1932,  3.5651, -0.6899, -1.8201,
#          1.4063, -1.6277, -1.5361,  1.0264, -2.9781], requires_grad=True)
# Updated bias: tensor([22.2682], requires_grad=True)
# Loss after update: 23.434574
# Loss before update: 23.324600
# Weight grad norm: 0.974086, Bias grad: -0.441193
# Updated weights: tensor([-0.5964,  0.5939, -0.1732,  0.7859, -0.2480,  3.5330, -0.6696, -1.8677,
#          1.4321, -1.6184, -1.5584,  1.0195, -3.0138], requires_grad=True)
# Updated bias: tensor([22.3166], requires_grad=True)
# Loss after update: 23.313206
# Loss before update: 23.216921
# Weight grad norm: 0.937466, Bias grad: -0.360481
# Updated weights: tensor([-0.6094,  0.6082, -0.1700,  0.7768, -0.3016,  3.5016, -0.6498, -1.9133,
#          1.4571, -1.6101, -1.5793,  1.0130, -3.0475], requires_grad=True)
# Updated bias: tensor([22.3562], requires_grad=True)
# Loss after update: 23.206863
# Loss before update: 23.121317
# Weight grad norm: 0.902780, Bias grad: -0.294540
# Updated weights: tensor([-0.6217,  0.6219, -0.1670,  0.7690, -0.3539,  3.4712, -0.6304, -1.9570,
#          1.4812, -1.6025, -1.5988,  1.0067, -3.0794], requires_grad=True)
# Updated bias: tensor([22.3885], requires_grad=True)
# Loss after update: 23.112324
# Loss before update: 23.035425
# Weight grad norm: 0.869827, Bias grad: -0.240662
# Updated weights: tensor([-0.6333,  0.6352, -0.1641,  0.7622, -0.4050,  3.4417, -0.6116, -1.9989,
#          1.5046, -1.5958, -1.6171,  1.0008, -3.1095], requires_grad=True)
# Updated bias: tensor([22.4149], requires_grad=True)
# Loss after update: 23.027300
# Loss before update: 22.957537
# Weight grad norm: 0.838441, Bias grad: -0.196632
# Updated weights: tensor([-0.6442,  0.6481, -0.1614,  0.7564, -0.4547,  3.4132, -0.5932, -2.0392,
#          1.5273, -1.5898, -1.6343,  0.9951, -3.1381], requires_grad=True)
# Updated bias: tensor([22.4365], requires_grad=True)
# Loss after update: 22.950138
# Loss before update: 22.886400
# Weight grad norm: 0.808489, Bias grad: -0.160664
# Updated weights: tensor([-0.6546,  0.6606, -0.1588,  0.7514, -0.5032,  3.3857, -0.5752, -2.0778,
#          1.5493, -1.5844, -1.6505,  0.9897, -3.1651], requires_grad=True)
# Updated bias: tensor([22.4541], requires_grad=True)
# Loss after update: 22.879618
# Loss before update: 22.821081
# Weight grad norm: 0.779857, Bias grad: -0.131279
# Updated weights: tensor([-0.6643,  0.6728, -0.1563,  0.7470, -0.5503,  3.3592, -0.5577, -2.1150,
#          1.5707, -1.5796, -1.6659,  0.9845, -3.1908], requires_grad=True)
# Updated bias: tensor([22.4685], requires_grad=True)
# Loss after update: 22.814838
# Loss before update: 22.760855
# Weight grad norm: 0.752452, Bias grad: -0.107258
# Updated weights: tensor([-0.6736,  0.6845, -0.1538,  0.7432, -0.5962,  3.3337, -0.5406, -2.1507,
#          1.5915, -1.5754, -1.6804,  0.9794, -3.2151], requires_grad=True)
# Updated bias: tensor([22.4802], requires_grad=True)
# Loss after update: 22.755087
# Loss before update: 22.705147
# Weight grad norm: 0.726191, Bias grad: -0.087643
# Updated weights: tensor([-0.6824,  0.6959, -0.1515,  0.7398, -0.6408,  3.3091, -0.5240, -2.1850,
#          1.6117, -1.5718, -1.6942,  0.9746, -3.2382], requires_grad=True)
# Updated bias: tensor([22.4899], requires_grad=True)
# Loss after update: 22.699810
# Loss before update: 22.653505
# Weight grad norm: 0.701003, Bias grad: -0.071617
# Updated weights: tensor([-0.6907,  0.7070, -0.1491,  0.7369, -0.6842,  3.2854, -0.5078, -2.2181,
#          1.6314, -1.5686, -1.7073,  0.9700, -3.2602], requires_grad=True)
# Updated bias: tensor([22.4977], requires_grad=True)
# Loss after update: 22.648550
# Loss before update: 22.605541
# Weight grad norm: 0.676826, Bias grad: -0.058521
# Updated weights: tensor([-0.6986,  0.7177, -0.1469,  0.7344, -0.7263,  3.2627, -0.4919, -2.2499,
#          1.6505, -1.5659, -1.7198,  0.9655, -3.2811], requires_grad=True)
# Updated bias: tensor([22.5041], requires_grad=True)
# Loss after update: 22.600935
# Loss before update: 22.560936
# Weight grad norm: 0.653606, Bias grad: -0.047813
# Updated weights: tensor([-0.7062,  0.7281, -0.1446,  0.7321, -0.7672,  3.2409, -0.4765, -2.2805,
#          1.6691, -1.5636, -1.7317,  0.9611, -3.3010], requires_grad=True)
# Updated bias: tensor([22.5094], requires_grad=True)
# Loss after update: 22.556648
# Loss before update: 22.519403
# Weight grad norm: 0.631291, Bias grad: -0.039062
# Updated weights: tensor([-0.7134,  0.7381, -0.1424,  0.7301, -0.8070,  3.2199, -0.4616, -2.3100,
#          1.6872, -1.5617, -1.7430,  0.9570, -3.3199], requires_grad=True)
# Updated bias: tensor([22.5137], requires_grad=True)
# Loss after update: 22.515413
# Loss before update: 22.480705
# Weight grad norm: 0.609837, Bias grad: -0.031914
# Updated weights: tensor([-0.7202,  0.7479, -0.1401,  0.7284, -0.8456,  3.1997, -0.4470, -2.3384,
#          1.7049, -1.5602, -1.7539,  0.9529, -3.3379], requires_grad=True)
# Updated bias: tensor([22.5172], requires_grad=True)
# Loss after update: 22.476984
# Loss before update: 22.444622
# Weight grad norm: 0.589203, Bias grad: -0.026081
# Updated weights: tensor([-0.7268,  0.7574, -0.1379,  0.7268, -0.8830,  3.1803, -0.4328, -2.3658,
#          1.7221, -1.5591, -1.7642,  0.9491, -3.3550], requires_grad=True)
# Updated bias: tensor([22.5200], requires_grad=True)
# Loss after update: 22.441149
# Loss before update: 22.410957
# Weight grad norm: 0.569350, Bias grad: -0.021309
# Updated weights: tensor([-0.7331,  0.7666, -0.1357,  0.7254, -0.9193,  3.1618, -0.4189, -2.3921,
#          1.7388, -1.5583, -1.7742,  0.9453, -3.3714], requires_grad=True)
# Updated bias: tensor([22.5224], requires_grad=True)
# Loss after update: 22.407717
# Loss before update: 22.379532
# Weight grad norm: 0.550243, Bias grad: -0.017414
# Updated weights: tensor([-0.7391,  0.7755, -0.1335,  0.7241, -0.9546,  3.1439, -0.4055, -2.4175,
#          1.7552, -1.5578, -1.7837,  0.9417, -3.3870], requires_grad=True)
# Updated bias: tensor([22.5243], requires_grad=True)
# Loss after update: 22.376505
# Loss before update: 22.350187
# Weight grad norm: 0.531850, Bias grad: -0.014229
# Updated weights: tensor([-0.7448,  0.7842, -0.1312,  0.7230, -0.9888,  3.1268, -0.3924, -2.4420,
#          1.7711, -1.5576, -1.7928,  0.9382, -3.4018], requires_grad=True)
# Updated bias: tensor([22.5258], requires_grad=True)
# Loss after update: 22.347361
# Loss before update: 22.322773
# Weight grad norm: 0.514140, Bias grad: -0.011627
# Updated weights: tensor([-0.7503,  0.7925, -0.1290,  0.7219, -1.0219,  3.1103, -0.3798, -2.4656,
#          1.7867, -1.5577, -1.8016,  0.9349, -3.4160], requires_grad=True)
# Updated bias: tensor([22.5271], requires_grad=True)
# Loss after update: 22.320135
# Loss before update: 22.297157
# Weight grad norm: 0.497084, Bias grad: -0.009499
# Updated weights: tensor([-0.7556,  0.8007, -0.1268,  0.7210, -1.0541,  3.0945, -0.3674, -2.4883,
#          1.8018, -1.5580, -1.8100,  0.9316, -3.4295], requires_grad=True)
# Updated bias: tensor([22.5282], requires_grad=True)
# Loss after update: 22.294691
# Loss before update: 22.273216
# Weight grad norm: 0.480656, Bias grad: -0.007759
# Updated weights: tensor([-0.7606,  0.8085, -0.1245,  0.7201, -1.0853,  3.0793, -0.3555, -2.5103,
#          1.8167, -1.5586, -1.8181,  0.9285, -3.4424], requires_grad=True)
# Updated bias: tensor([22.5290], requires_grad=True)
# Loss after update: 22.270906
# Loss before update: 22.250826
# Weight grad norm: 0.464828, Bias grad: -0.006336
# Updated weights: tensor([-0.7655,  0.8162, -0.1223,  0.7193, -1.1155,  3.0648, -0.3438, -2.5314,
#          1.8311, -1.5593, -1.8259,  0.9255, -3.4547], requires_grad=True)
# Updated bias: tensor([22.5297], requires_grad=True)
# Loss after update: 22.248669
# Loss before update: 22.229885
# Weight grad norm: 0.449579, Bias grad: -0.005176
# Updated weights: tensor([-0.7702,  0.8236, -0.1200,  0.7186, -1.1448,  3.0508, -0.3325, -2.5518,
#          1.8453, -1.5603, -1.8333,  0.9226, -3.4664], requires_grad=True)
# Updated bias: tensor([22.5303], requires_grad=True)
# Loss after update: 22.227867
# Loss before update: 22.210297
# Weight grad norm: 0.434884, Bias grad: -0.004223
# Updated weights: tensor([-0.7747,  0.8307, -0.1177,  0.7179, -1.1732,  3.0374, -0.3216, -2.5714,
#          1.8591, -1.5615, -1.8405,  0.9198, -3.4776], requires_grad=True)
# Updated bias: tensor([22.5307], requires_grad=True)
# Loss after update: 22.208408
# Loss before update: 22.191965
# Weight grad norm: 0.420722, Bias grad: -0.003452
# Updated weights: tensor([-0.7790,  0.8377, -0.1154,  0.7172, -1.2008,  3.0245, -0.3110, -2.5904,
#          1.8726, -1.5629, -1.8475,  0.9171, -3.4884], requires_grad=True)
# Updated bias: tensor([22.5311], requires_grad=True)
# Loss after update: 22.190201
# Loss before update: 22.174805
# Weight grad norm: 0.407073, Bias grad: -0.002823
# Updated weights: tensor([-0.7832,  0.8445, -0.1131,  0.7166, -1.2274,  3.0121, -0.3006, -2.6086,
#          1.8858, -1.5645, -1.8542,  0.9145, -3.4986], requires_grad=True)
# Updated bias: tensor([22.5314], requires_grad=True)
# Loss after update: 22.173153
# Loss before update: 22.158741
# Weight grad norm: 0.393916, Bias grad: -0.002308
# Updated weights: tensor([-0.7873,  0.8510, -0.1108,  0.7161, -1.2533,  3.0001, -0.2906, -2.6263,
#          1.8986, -1.5662, -1.8606,  0.9120, -3.5084], requires_grad=True)
# Updated bias: tensor([22.5317], requires_grad=True)
# Loss after update: 22.157194
# Loss before update: 22.143698
# Weight grad norm: 0.381232, Bias grad: -0.001888
# Updated weights: tensor([-0.7911,  0.8573, -0.1084,  0.7155, -1.2784,  2.9887, -0.2810, -2.6433,
#          1.9113, -1.5681, -1.8668,  0.9096, -3.5177], requires_grad=True)
# Updated bias: tensor([22.5319], requires_grad=True)
# Loss after update: 22.142246
# Loss before update: 22.129604
# Weight grad norm: 0.369004, Bias grad: -0.001541
# Updated weights: tensor([-0.7949,  0.8635, -0.1061,  0.7150, -1.3026,  2.9777, -0.2716, -2.6597,
#          1.9236, -1.5701, -1.8728,  0.9073, -3.5267], requires_grad=True)
# Updated bias: tensor([22.5321], requires_grad=True)
# Loss after update: 22.128242
# Loss before update: 22.116400
# Weight grad norm: 0.357215, Bias grad: -0.001259
# Updated weights: tensor([-0.7985,  0.8694, -0.1037,  0.7145, -1.3262,  2.9671, -0.2624, -2.6755,
#          1.9357, -1.5723, -1.8786,  0.9051, -3.5352], requires_grad=True)
# Updated bias: tensor([22.5322], requires_grad=True)
# Loss after update: 22.115124
# Loss before update: 22.104021
# Weight grad norm: 0.345848, Bias grad: -0.001030
# Updated weights: tensor([-0.8020,  0.8752, -0.1014,  0.7140, -1.3489,  2.9570, -0.2536, -2.6907,
#          1.9475, -1.5746, -1.8842,  0.9029, -3.5434], requires_grad=True)
# Updated bias: tensor([22.5323], requires_grad=True)
# Loss after update: 22.102831
# Loss before update: 22.092421
# Weight grad norm: 0.334887, Bias grad: -0.000839
# Updated weights: tensor([-0.8054,  0.8808, -0.0990,  0.7136, -1.3710,  2.9472, -0.2451, -2.7054,
#          1.9590, -1.5770, -1.8896,  0.9009, -3.5512], requires_grad=True)
# Updated bias: tensor([22.5324], requires_grad=True)
# Loss after update: 22.091301
# Loss before update: 22.081539
# Weight grad norm: 0.324317, Bias grad: -0.000686
# Updated weights: tensor([-0.8087,  0.8862, -0.0966,  0.7131, -1.3924,  2.9378, -0.2368, -2.7196,
#          1.9703, -1.5795, -1.8948,  0.8989, -3.5587], requires_grad=True)
# Updated bias: tensor([22.5325], requires_grad=True)
# Loss after update: 22.080492
# Loss before update: 22.071335
# Weight grad norm: 0.314124, Bias grad: -0.000565
# Updated weights: tensor([-0.8118,  0.8915, -0.0942,  0.7127, -1.4131,  2.9288, -0.2288, -2.7333,
#          1.9814, -1.5822, -1.8998,  0.8969, -3.5659], requires_grad=True)
# Updated bias: tensor([22.5325], requires_grad=True)
# Loss after update: 22.070351
# Loss before update: 22.061758
# Weight grad norm: 0.304295, Bias grad: -0.000458
# Updated weights: tensor([-0.8149,  0.8965, -0.0919,  0.7123, -1.4332,  2.9201, -0.2210, -2.7465,
#          1.9923, -1.5849, -1.9047,  0.8951, -3.5727], requires_grad=True)
# Updated bias: tensor([22.5326], requires_grad=True)
# Loss after update: 22.060837
# Loss before update: 22.052773
# Weight grad norm: 0.294814, Bias grad: -0.000381
# Updated weights: tensor([-0.8179,  0.9015, -0.0895,  0.7119, -1.4526,  2.9118, -0.2135, -2.7592,
#          2.0029, -1.5877, -1.9094,  0.8933, -3.5793], requires_grad=True)
# Updated bias: tensor([22.5326], requires_grad=True)
# Loss after update: 22.051907
# Loss before update: 22.044336
# Weight grad norm: 0.285671, Bias grad: -0.000305
# Updated weights: tensor([-0.8207,  0.9063, -0.0871,  0.7115, -1.4714,  2.9037, -0.2062, -2.7715,
#          2.0133, -1.5906, -1.9139,  0.8916, -3.5856], requires_grad=True)
# Updated bias: tensor([22.5327], requires_grad=True)
# Loss after update: 22.043522
# Loss before update: 22.036415
# Weight grad norm: 0.276852, Bias grad: -0.000256
# Updated weights: tensor([-0.8235,  0.9109, -0.0847,  0.7111, -1.4897,  2.8960, -0.1991, -2.7833,
#          2.0235, -1.5936, -1.9183,  0.8900, -3.5916], requires_grad=True)
# Updated bias: tensor([22.5327], requires_grad=True)
# Loss after update: 22.035650
# Loss before update: 22.028973
# Weight grad norm: 0.268345, Bias grad: -0.000217
# Updated weights: tensor([-0.8262,  0.9154, -0.0823,  0.7108, -1.5073,  2.8886, -0.1923, -2.7948,
#          2.0335, -1.5966, -1.9225,  0.8884, -3.5973], requires_grad=True)
# Updated bias: tensor([22.5327], requires_grad=True)
# Loss after update: 22.028255
# Loss before update: 22.021978
# Weight grad norm: 0.260140, Bias grad: -0.000179
# Updated weights: tensor([-0.8288,  0.9198, -0.0799,  0.7104, -1.5244,  2.8814, -0.1857, -2.8058,
#          2.0433, -1.5997, -1.9266,  0.8869, -3.6028], requires_grad=True)
# Updated bias: tensor([22.5327], requires_grad=True)
# Loss after update: 22.021303
# Loss before update: 22.015409
# Weight grad norm: 0.252225, Bias grad: -0.000141
# Updated weights: tensor([-0.8313,  0.9240, -0.0775,  0.7100, -1.5410,  2.8745, -0.1793, -2.8164,
#          2.0529, -1.6029, -1.9306,  0.8854, -3.6081], requires_grad=True)
# Updated bias: tensor([22.5327], requires_grad=True)
# Loss after update: 22.014774
# Loss before update: 22.009230
# Weight grad norm: 0.244590, Bias grad: -0.000103
# Updated weights: tensor([-0.8338,  0.9281, -0.0751,  0.7097, -1.5571,  2.8679, -0.1731, -2.8267,
#          2.0623, -1.6062, -1.9345,  0.8840, -3.6132], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 22.008633
# Loss before update: 22.003416
# Weight grad norm: 0.237225, Bias grad: -0.000092
# Updated weights: tensor([-0.8362,  0.9320, -0.0728,  0.7094, -1.5726,  2.8615, -0.1671, -2.8366,
#          2.0716, -1.6095, -1.9382,  0.8826, -3.6180], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 22.002855
# Loss before update: 21.997948
# Weight grad norm: 0.230120, Bias grad: -0.000092
# Updated weights: tensor([-0.8385,  0.9359, -0.0704,  0.7090, -1.5876,  2.8554, -0.1613, -2.8462,
#          2.0806, -1.6128, -1.9418,  0.8813, -3.6227], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.997417
# Loss before update: 21.992802
# Weight grad norm: 0.223265, Bias grad: -0.000092
# Updated weights: tensor([-0.8407,  0.9396, -0.0680,  0.7087, -1.6022,  2.8495, -0.1557, -2.8554,
#          2.0895, -1.6162, -1.9453,  0.8801, -3.6271], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.992308
# Loss before update: 21.987957
# Weight grad norm: 0.216652, Bias grad: -0.000092
# Updated weights: tensor([-0.8429,  0.9432, -0.0657,  0.7084, -1.6163,  2.8438, -0.1503, -2.8643,
#          2.0982, -1.6196, -1.9486,  0.8789, -3.6314], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.987490
# Loss before update: 21.983395
# Weight grad norm: 0.210272, Bias grad: -0.000092
# Updated weights: tensor([-0.8450,  0.9467, -0.0633,  0.7080, -1.6300,  2.8383, -0.1451, -2.8728,
#          2.1068, -1.6231, -1.9519,  0.8777, -3.6355], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.982952
# Loss before update: 21.979094
# Weight grad norm: 0.204116, Bias grad: -0.000092
# Updated weights: tensor([-0.8470,  0.9501, -0.0610,  0.7077, -1.6432,  2.8330, -0.1400, -2.8811,
#          2.1152, -1.6266, -1.9551,  0.8766, -3.6394], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.978678
# Loss before update: 21.975042
# Weight grad norm: 0.198177, Bias grad: -0.000092
# Updated weights: tensor([-0.8490,  0.9534, -0.0586,  0.7074, -1.6560,  2.8279, -0.1351, -2.8891,
#          2.1234, -1.6302, -1.9581,  0.8755, -3.6432], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.974651
# Loss before update: 21.971224
# Weight grad norm: 0.192447, Bias grad: -0.000092
# Updated weights: tensor([-0.8509,  0.9566, -0.0563,  0.7071, -1.6684,  2.8230, -0.1303, -2.8968,
#          2.1315, -1.6337, -1.9611,  0.8745, -3.6468], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.970854
# Loss before update: 21.967621
# Weight grad norm: 0.186917, Bias grad: -0.000092
# Updated weights: tensor([-0.8528,  0.9597, -0.0540,  0.7068, -1.6805,  2.8183, -0.1257, -2.9042,
#          2.1394, -1.6373, -1.9640,  0.8735, -3.6503], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.967272
# Loss before update: 21.964222
# Weight grad norm: 0.181581, Bias grad: -0.000091
# Updated weights: tensor([-0.8546,  0.9627, -0.0517,  0.7065, -1.6921,  2.8137, -0.1213, -2.9114,
#          2.1472, -1.6409, -1.9667,  0.8725, -3.6536], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.963890
# Loss before update: 21.961014
# Weight grad norm: 0.176432, Bias grad: -0.000092
# Updated weights: tensor([-0.8564,  0.9656, -0.0495,  0.7062, -1.7034,  2.8093, -0.1170, -2.9183,
#          2.1549, -1.6446, -1.9694,  0.8716, -3.6568], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.960703
# Loss before update: 21.957983
# Weight grad norm: 0.171463, Bias grad: -0.000092
# Updated weights: tensor([-0.8581,  0.9685, -0.0472,  0.7059, -1.7143,  2.8051, -0.1129, -2.9250,
#          2.1624, -1.6482, -1.9720,  0.8707, -3.6599], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.957689
# Loss before update: 21.955120
# Weight grad norm: 0.166668, Bias grad: -0.000091
# Updated weights: tensor([-0.8597,  0.9712, -0.0449,  0.7057, -1.7248,  2.8010, -0.1088, -2.9314,
#          2.1697, -1.6519, -1.9746,  0.8698, -3.6628], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.954844
# Loss before update: 21.952417
# Weight grad norm: 0.162040, Bias grad: -0.000092
# Updated weights: tensor([-0.8613,  0.9739, -0.0427,  0.7054, -1.7351,  2.7971, -0.1049, -2.9376,
#          2.1770, -1.6556, -1.9770,  0.8690, -3.6657], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.952152
# Loss before update: 21.949860
# Weight grad norm: 0.157574, Bias grad: -0.000092
# Updated weights: tensor([-0.8629,  0.9765, -0.0405,  0.7051, -1.7450,  2.7933, -0.1012, -2.9436,
#          2.1841, -1.6593, -1.9794,  0.8682, -3.6684], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.949612
# Loss before update: 21.947441
# Weight grad norm: 0.153263, Bias grad: -0.000091
# Updated weights: tensor([-0.8644,  0.9790, -0.0383,  0.7048, -1.7546,  2.7896, -0.0975, -2.9494,
#          2.1911, -1.6630, -1.9817,  0.8675, -3.6710], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.947206
# Loss before update: 21.945152
# Weight grad norm: 0.149101, Bias grad: -0.000091
# Updated weights: tensor([-0.8659,  0.9814, -0.0361,  0.7045, -1.7639,  2.7861, -0.0940, -2.9550,
#          2.1980, -1.6667, -1.9839,  0.8667, -3.6735], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.944931
# Loss before update: 21.942986
# Weight grad norm: 0.145084, Bias grad: -0.000091
# Updated weights: tensor([-0.8673,  0.9838, -0.0339,  0.7043, -1.7729,  2.7827, -0.0906, -2.9604,
#          2.2047, -1.6704, -1.9861,  0.8660, -3.6759], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.942774
# Loss before update: 21.940935
# Weight grad norm: 0.141207, Bias grad: -0.000092
# Updated weights: tensor([-0.8687,  0.9861, -0.0318,  0.7040, -1.7816,  2.7794, -0.0873, -2.9656,
#          2.2113, -1.6741, -1.9882,  0.8653, -3.6782], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.940737
# Loss before update: 21.938990
# Weight grad norm: 0.137463, Bias grad: -0.000092
# Updated weights: tensor([-0.8701,  0.9883, -0.0297,  0.7037, -1.7900,  2.7762, -0.0842, -2.9706,
#          2.2179, -1.6778, -1.9902,  0.8647, -3.6804], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.938801
# Loss before update: 21.937145
# Weight grad norm: 0.133849, Bias grad: -0.000091
# Updated weights: tensor([-0.8714,  0.9904, -0.0275,  0.7035, -1.7982,  2.7732, -0.0811, -2.9754,
#          2.2243, -1.6815, -1.9922,  0.8641, -3.6825], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.936970
# Loss before update: 21.935400
# Weight grad norm: 0.130359, Bias grad: -0.000092
# Updated weights: tensor([-0.8727,  0.9925, -0.0255,  0.7032, -1.8061,  2.7702, -0.0781, -2.9801,
#          2.2306, -1.6852, -1.9941,  0.8635, -3.6846], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.935230
# Loss before update: 21.933743
# Weight grad norm: 0.126989, Bias grad: -0.000092
# Updated weights: tensor([-0.8740,  0.9946, -0.0234,  0.7030, -1.8137,  2.7674, -0.0752, -2.9846,
#          2.2368, -1.6889, -1.9960,  0.8629, -3.6865], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.933580
# Loss before update: 21.932169
# Weight grad norm: 0.123735, Bias grad: -0.000092
# Updated weights: tensor([-0.8752,  0.9965, -0.0213,  0.7027, -1.8212,  2.7646, -0.0724, -2.9889,
#          2.2429, -1.6926, -1.9978,  0.8623, -3.6884], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.932016
# Loss before update: 21.930676
# Weight grad norm: 0.120592, Bias grad: -0.000092
# Updated weights: tensor([-0.8764,  0.9985, -0.0193,  0.7025, -1.8283,  2.7620, -0.0697, -2.9931,
#          2.2488, -1.6963, -1.9995,  0.8618, -3.6902], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.930531
# Loss before update: 21.929255
# Weight grad norm: 0.117557, Bias grad: -0.000091
# Updated weights: tensor([-0.8775,  1.0003, -0.0173,  0.7022, -1.8353,  2.7594, -0.0671, -2.9971,
#          2.2547, -1.7000, -2.0012,  0.8613, -3.6920], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.929119
# Loss before update: 21.927906
# Weight grad norm: 0.114624, Bias grad: -0.000092
# Updated weights: tensor([-0.8786,  1.0021, -0.0153,  0.7020, -1.8420,  2.7569, -0.0646, -3.0010,
#          2.2605, -1.7037, -2.0028,  0.8608, -3.6937], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.927774
# Loss before update: 21.926624
# Weight grad norm: 0.111791, Bias grad: -0.000092
# Updated weights: tensor([-0.8797,  1.0039, -0.0133,  0.7017, -1.8486,  2.7545, -0.0622, -3.0048,
#          2.2662, -1.7073, -2.0044,  0.8603, -3.6953], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.926497
# Loss before update: 21.925404
# Weight grad norm: 0.109054, Bias grad: -0.000092
# Updated weights: tensor([-0.8808,  1.0056, -0.0113,  0.7015, -1.8549,  2.7522, -0.0598, -3.0084,
#          2.2718, -1.7110, -2.0060,  0.8598, -3.6969], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.925283
# Loss before update: 21.924242
# Weight grad norm: 0.106409, Bias grad: -0.000091
# Updated weights: tensor([-0.8818,  1.0073, -0.0094,  0.7013, -1.8610,  2.7500, -0.0575, -3.0119,
#          2.2773, -1.7146, -2.0075,  0.8594, -3.6984], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.924128
# Loss before update: 21.923134
# Weight grad norm: 0.103853, Bias grad: -0.000091
# Updated weights: tensor([-0.8828,  1.0089, -0.0075,  0.7010, -1.8669,  2.7478, -0.0553, -3.0153,
#          2.2827, -1.7183, -2.0089,  0.8590, -3.6998], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.923027
# Loss before update: 21.922081
# Weight grad norm: 0.101383, Bias grad: -0.000092
# Updated weights: tensor([-0.8838,  1.0105, -0.0056,  0.7008, -1.8726,  2.7457, -0.0532, -3.0186,
#          2.2881, -1.7219, -2.0103,  0.8586, -3.7012], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.921980
# Loss before update: 21.921076
# Weight grad norm: 0.098995, Bias grad: -0.000092
# Updated weights: tensor([-0.8848,  1.0120, -0.0037,  0.7006, -1.8782,  2.7437, -0.0511, -3.0217,
#          2.2933, -1.7255, -2.0117,  0.8582, -3.7025], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.920977
# Loss before update: 21.920116
# Weight grad norm: 0.096686, Bias grad: -0.000091
# Updated weights: tensor([-8.8568e-01,  1.0135e+00, -1.8762e-03,  7.0036e-01, -1.8836e+00,
#          2.7418e+00, -4.9107e-02, -3.0247e+00,  2.2985e+00, -1.7291e+00,
#         -2.0130e+00,  8.5781e-01, -3.7038e+00], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.920023
# Loss before update: 21.919203
# Weight grad norm: 0.094454, Bias grad: -0.000092
# Updated weights: tensor([-8.8659e-01,  1.0149e+00, -4.2917e-05,  7.0014e-01, -1.8888e+00,
#          2.7399e+00, -4.7169e-02, -3.0277e+00,  2.3035e+00, -1.7326e+00,
#         -2.0143e+00,  8.5744e-01, -3.7050e+00], requires_grad=True)
# Updated bias: tensor([22.5328], requires_grad=True)
# Loss after update: 21.919113

# %%
# Works by hand but still a loss
print("Final weights:", w)
print("Final bias:", b)
# Out:
# Final weights: tensor([-8.8738e-01,  1.0162e+00,  1.5896e-03,  6.9994e-01, -1.8933e+00,
#          2.7383e+00, -4.5478e-02, -3.0302e+00,  2.3080e+00, -1.7358e+00,
#         -2.0154e+00,  8.5713e-01, -3.7061e+00], requires_grad=True)
# Final bias: tensor([22.5328], requires_grad=True)

# %% [markdown]
# We almost reach the loss from scikit learn, but not quite.

# %%
# Trying with an adam optimizer
import torch.optim as optim
# Initialize the optimizer
optimizer = optim.Adam([w, b], lr=0.01)
# Training the model using Adam optimizer - 100 epochs
for epoch in range(100):
    optimizer.zero_grad()  # Zero the gradients
    predictions = linear_model(X_torch_scaled, w, b)  # Forward pass
    loss = mean_squared_error(y_torch, predictions)  # Compute loss
    loss.backward()  # Backward pass
    optimizer.step()  # Update weights and bias

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.6f}")
# Out:
# Epoch 0, Loss: 21.894833
# Epoch 10, Loss: 21.895378
# Epoch 20, Loss: 21.895042
# Epoch 30, Loss: 21.894846
# Epoch 40, Loss: 21.894855
# Epoch 50, Loss: 21.894835
# Epoch 60, Loss: 21.894836
# Epoch 70, Loss: 21.894835
# Epoch 80, Loss: 21.894833
# Epoch 90, Loss: 21.894833

# %% [markdown]
# Seems we cannot optimize much further.

# %% [markdown]
# ### Linear regression class - creating an instance of the model

# %%
# Doing it with nn
import torch.nn as nn
class LinearRegressionModel(nn.Module):
    def __init__(self, input_dim):
        super(LinearRegressionModel, self).__init__()
        self.linear = nn.Linear(input_dim, 1)  # Linear layer # input_dim is the number of features
        # 1 is the output dimension (single target variable), it would be 2 for a 2D output, etc.

    def forward(self, x):
        return self.linear(x)  # Forward pass through the linear layer

# %%
? nn.Linear
# Out:
# Init signature:
#  nn.Linear(
#     in_features: int,
#     out_features: int,
#     bias: bool = True,
#     device=None,
#     dtype=None,
# ) -> None
# Docstring:
# Applies an affine linear transformation to the incoming data: :math:`y = xA^T + b`.
#
# This module supports :ref:`TensorFloat32<tf32_on_ampere>`.
#
# On certain ROCm devices, when using float16 inputs this module will use :ref:`different precision<fp16_on_mi200>` for backward.
#
# Args:
#     in_features: size of each input sample
#     out_features: size of each output sample
#     bias: If set to ``False``, the layer will not learn an additive bias.
#         Default: ``True``
#
# Shape:
#     - Input: :math:`(*, H_{in})` where :math:`*` means any number of
#       dimensions including none and :math:`H_{in} = \text{in\_features}`.
#     - Output: :math:`(*, H_{out})` where all but the last dimension
#       are the same shape as the input and :math:`H_{out} = \text{out\_features}`.
#
# Attributes:
#     weight: the learnable weights of the module of shape
#         :math:`(\text{out\_features}, \text{in\_features})`. The values are
#         initialized from :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})`, where
#         :math:`k = \frac{1}{\text{in\_features}}`
#     bias:   the learnable bias of the module of shape :math:`(\text{out\_features})`.
#             If :attr:`bias` is ``True``, the values are initialized from
#             :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})` where
#             :math:`k = \frac{1}{\text{in\_features}}`
#
# Examples::
#
#     >>> m = nn.Linear(20, 30)
#     >>> input = torch.randn(128, 20)
#     >>> output = m(input)
#     >>> print(output.size())
#     torch.Size([128, 30])
# Init docstring: Initialize internal Module state, shared by both nn.Module and ScriptModule.
# File:           ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/linear.py
# Type:           type
# Subclasses:     NonDynamicallyQuantizableLinear, LazyLinear, Linear, LinearBn1d, Linear

# %%
# Create an instance of the model
model_nn = LinearRegressionModel(input_dim=X_torch_scaled.shape[1]) # initialize initt with input dims
# Define the loss function and optimizer
criterion = nn.MSELoss()  # Mean Squared Error loss
optimizer_nn = optim.Adam(model_nn.parameters(), lr=0.1)  # Adam optimizer
# Training the model using PyTorch's nn module - 100 epochs
for epoch in range(1000):
    optimizer_nn.zero_grad()  # Zero the gradients
    predictions = model_nn(X_torch_scaled)  # Forward pass # Run the forward pass with the actual data
    loss = criterion(predictions.squeeze(), y_torch)  # Compute loss
    loss.backward()  # Backward pass
    optimizer_nn.step()  # Update weights and bias

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.6f}")
# Out:
# Epoch 0, Loss: 600.184937
# Epoch 10, Loss: 517.189880
# Epoch 20, Loss: 463.325897
# Epoch 30, Loss: 419.188873
# Epoch 40, Loss: 379.693054
# Epoch 50, Loss: 344.574036
# Epoch 60, Loss: 312.496460
# Epoch 70, Loss: 282.924133
# Epoch 80, Loss: 255.754135
# Epoch 90, Loss: 230.863541
# Epoch 100, Loss: 208.121475
# Epoch 110, Loss: 187.395691
# Epoch 120, Loss: 168.558701
# Epoch 130, Loss: 151.487320
# Epoch 140, Loss: 136.062363
# Epoch 150, Loss: 122.168045
# Epoch 160, Loss: 109.692093
# Epoch 170, Loss: 98.526291
# Epoch 180, Loss: 88.566353
# Epoch 190, Loss: 79.712418
# Epoch 200, Loss: 71.869034
# Epoch 210, Loss: 64.945465
# Epoch 220, Loss: 58.855862
# Epoch 230, Loss: 53.519291
# Epoch 240, Loss: 48.859955
# Epoch 250, Loss: 44.807106
# Epoch 260, Loss: 41.295170
# Epoch 270, Loss: 38.263466
# Epoch 280, Loss: 35.656479
# Epoch 290, Loss: 33.423309
# Epoch 300, Loss: 31.517809
# Epoch 310, Loss: 29.898270
# Epoch 320, Loss: 28.527170
# Epoch 330, Loss: 27.370983
# Epoch 340, Loss: 26.399862
# Epoch 350, Loss: 25.587381
# Epoch 360, Loss: 24.910341
# Epoch 370, Loss: 24.348394
# Epoch 380, Loss: 23.883816
# Epoch 390, Loss: 23.501259
# Epoch 400, Loss: 23.187490
# Epoch 410, Loss: 22.931150
# Epoch 420, Loss: 22.722572
# Epoch 430, Loss: 22.553522
# Epoch 440, Loss: 22.417046
# Epoch 450, Loss: 22.307308
# Epoch 460, Loss: 22.219414
# Epoch 470, Loss: 22.149294
# Epoch 480, Loss: 22.093578
# Epoch 490, Loss: 22.049479
# Epoch 500, Loss: 22.014711
# Epoch 510, Loss: 21.987411
# Epoch 520, Loss: 21.966057
# Epoch 530, Loss: 21.949421
# Epoch 540, Loss: 21.936514
# Epoch 550, Loss: 21.926537
# Epoch 560, Loss: 21.918856
# Epoch 570, Loss: 21.912966
# Epoch 580, Loss: 21.908466
# Epoch 590, Loss: 21.905045
# Epoch 600, Loss: 21.902452
# Epoch 610, Loss: 21.900496
# Epoch 620, Loss: 21.899025
# Epoch 630, Loss: 21.897924
# Epoch 640, Loss: 21.897102
# Epoch 650, Loss: 21.896492
# Epoch 660, Loss: 21.896044
# Epoch 670, Loss: 21.895710
# Epoch 680, Loss: 21.895466
# Epoch 690, Loss: 21.895290
# Epoch 700, Loss: 21.895159
# Epoch 710, Loss: 21.895065
# Epoch 720, Loss: 21.894999
# Epoch 730, Loss: 21.894949
# Epoch 740, Loss: 21.894913
# Epoch 750, Loss: 21.894890
# Epoch 760, Loss: 21.894873
# Epoch 770, Loss: 21.894857
# Epoch 780, Loss: 21.894850
# Epoch 790, Loss: 21.894846
# Epoch 800, Loss: 21.894840
# Epoch 810, Loss: 21.894838
# Epoch 820, Loss: 21.894835
# Epoch 830, Loss: 21.894836
# Epoch 840, Loss: 21.894833
# Epoch 850, Loss: 21.894833
# Epoch 860, Loss: 21.894833
# Epoch 870, Loss: 21.894833
# Epoch 880, Loss: 21.894833
# Epoch 890, Loss: 21.894831
# Epoch 900, Loss: 21.894831
# Epoch 910, Loss: 21.894831
# Epoch 920, Loss: 21.894833
# Epoch 930, Loss: 21.894833
# Epoch 940, Loss: 21.894829
# Epoch 950, Loss: 21.894831
# Epoch 960, Loss: 21.894833
# Epoch 970, Loss: 21.894833
# Epoch 980, Loss: 21.894833
# Epoch 990, Loss: 21.894833

# %% [markdown]
# ### A more hands on way to create the model
#
# ```python

# %%
# Another way to do it
model = nn.Linear(X_torch_scaled.shape[1], 1)  # Create a linear model
print("Model parameters:", list(model.parameters()))  # Display model parameters
model.weight, model.bias  # Access weights and bias
# Out:
# Model parameters: [Parameter containing:
# tensor([[ 0.0508,  0.1022, -0.1096,  0.0870,  0.1249, -0.2752, -0.1327,  0.1959,
#           0.1043, -0.1124,  0.0579,  0.1165, -0.0287]], requires_grad=True), Parameter containing:
# tensor([0.1348], requires_grad=True)]
# (Parameter containing:
#  tensor([[ 0.0508,  0.1022, -0.1096,  0.0870,  0.1249, -0.2752, -0.1327,  0.1959,
#            0.1043, -0.1124,  0.0579,  0.1165, -0.0287]], requires_grad=True),
#  Parameter containing:
#  tensor([0.1348], requires_grad=True))

# %%
predictions = model(X_torch_scaled)  # Forward pass

# %% [markdown]
# ### Trying to batch the data

# %%
from torch.utils.data import DataLoader, TensorDataset

# Create a dataset and dataloader
dataset = TensorDataset(X_torch_scaled, y_torch)  

# Create a DataLoader for batching - shuffle=True for random sampling
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ### Using the batching

# %%
import torch.nn.functional as F
# Use a stochastic gradient descent (SGD) optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)  # Stochastic Gradient Descent optimizer
# Training the model using DataLoader - 100 epochs
for epoch in range(100):
    for batch_X, batch_y in dataloader:  # Iterate over batches
        optimizer.zero_grad()  # Zero the gradients
        predictions = model(batch_X)  # Forward pass
        loss = F.mse_loss(predictions.squeeze(), batch_y)  # Compute loss
        loss.backward()  # Backward pass
        optimizer.step()  # Update weights and bias

    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.6f}")
