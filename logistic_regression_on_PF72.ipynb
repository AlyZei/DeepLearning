# %% [markdown]
# # The usual imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Jovian Pytorch tutorial for image classification

# %% [markdown]
# # Lore's function

# %%
 # import train data
path_train = "../experiments/datasets/PF00072/PF00072_full_aligned.csv"
train_df = pd.read_csv(path_train)
X_train = train_df["sequence"].values
y_train = train_df["label"].values
X_train = encode_sequence(X_train, tokens)
X_train = np.eye(len(tokens))[X_train].reshape(len(X_train), -1) # one-hot + flatten

# standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# fit logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# predict on test data
y_pred = model.predict(X_test_scaled)
y_pred_proba = model.predict_proba(X_test_scaled)
